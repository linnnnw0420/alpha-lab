# %% [markdown]
# # 01 — Data, fixed sampling, and momentum
# The runnable script is the tested source of truth. This notebook keeps the learning workflow interactive.

# %%
# %run ../examples/sampled_momentum_backtest.py
