# %% [markdown]
# # 05 — Reproducible experiment artifacts
# Runs record normalized configuration, source fingerprints, environment versions, metrics, and compact tables.

# %%
# %run ../examples/experiment_artifacts.py
