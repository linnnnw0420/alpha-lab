# %% [markdown]
# # 03 — Leakage-safe cross-sectional ML
# Training and test observations are split by whole dates; preprocessing is refit inside every window.

# %%
# %run ../examples/walk_forward_ml.py
