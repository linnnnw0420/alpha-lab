# %% [markdown]
# # 02 — Portfolio and transparent backtest
# Inspect `result.equity_curve`, `result.positions`, and `result.trades` after the script runs.

# %%
# %run ../examples/momentum_backtest.py
